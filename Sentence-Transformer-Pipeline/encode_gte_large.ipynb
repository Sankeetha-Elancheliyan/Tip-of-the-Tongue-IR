# %%
# !pip install faiss-cpu # Install faiss library
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 66.5 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
# prompt: write code to connect to the ngoogle drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
import faiss
import pickle
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv("/content/drive/MyDrive/filename.csv")
df.head()
# Out:
#    Unnamed: 0        id                                                url  \
# 0           0  67282749          https://en.wikipedia.org/wiki/Bert%20Meek
# 1           1  67282757           https://en.wikipedia.org/wiki/Pericastor
# 2           2  67282773  https://en.wikipedia.org/wiki/Dead%20Sea%20Museum
# 3           3  67282775  https://en.wikipedia.org/wiki/Massalongia%20rubra
# 4           4  67282780   https://en.wikipedia.org/wiki/Federica%20Ferraro
#
#                title                                               text
# 0          Bert Meek  Bert Bookham Meek (September 2, 1883 - Septemb...
# 1         Pericastor  In Greek mythology, Pericastor (Ancient Greek:...
# 2    Dead Sea Museum  The Dead Sea Museum (Arabic: متحف البحر الميت)...
# 3  Massalongia rubra  Massalongia rubra is a species of gall midge w...
# 4   Federica Ferraro  Federica Ferraro (born 18 August 1988) is an I...

# %%
csv_file = "/content/drive/MyDrive/filename.csv"
faiss_index_file = "faiss_index.pkl"
embedding_model_name = "sentence-transformers/all-MiniLM-L6-v2"  # Small, efficient model # Hugging Face model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = SentenceTransformer(embedding_model_name).to(device)

# Load or Create FAISS Index
try:
    with open(faiss_index_file, "rb") as f:
        faiss_index, df = pickle.load(f)
    print("Loaded precomputed FAISS index for 50K rows.")
except FileNotFoundError:
    print("FAISS index not found. Creating a new one...")

    # Load Wikipedia Movie Data
    df = pd.read_csv(csv_file)

    # Select the first 50,000 rows
    df = df.head(10000)

    # Encode movie descriptions and print progress
    movie_texts = df["text"].astype(str).tolist()
    embeddings = []

    for i, text in enumerate(movie_texts):
        print(f"Encoding document {i+1}/50000...")
        embedding = model.encode(text, convert_to_tensor=True).cpu().numpy()
        embeddings.append(embedding)

    embeddings = np.array(embeddings)  # Convert list to NumPy array

    # Create FAISS Index
    d = embeddings.shape[1]  # Embedding dimension
    faiss_index = faiss.IndexFlatL2(d)  # L2 (Euclidean) similarity search
    faiss_index.add(embeddings)  # Add 50K embeddings to the index

    # Save FAISS index
    with open(faiss_index_file, "wb") as f:
        pickle.dump((faiss_index, df), f)

    print("FAISS index for 50K rows saved.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Encoding document 5002/50000...
# Encoding document 5003/50000...
# Encoding document 5004/50000...
# Encoding document 5005/50000...
# Encoding document 5006/50000...
# Encoding document 5007/50000...
# Encoding document 5008/50000...
# Encoding document 5009/50000...
# Encoding document 5010/50000...
# Encoding document 5011/50000...
# Encoding document 5012/50000...
# Encoding document 5013/50000...
# Encoding document 5014/50000...
# Encoding document 5015/50000...
# Encoding document 5016/50000...
# Encoding document 5017/50000...
# Encoding document 5018/50000...
# Encoding document 5019/50000...
# Encoding document 5020/50000...
# Encoding document 5021/50000...
# Encoding document 5022/50000...
# Encoding document 5023/50000...
# Encoding document 5024/50000...
# Encoding document 5025/50000...
# Encoding document 5026/50000...
# Encoding document 5027/50000...
# Encoding document 5028/50000...
# Encoding document 5029/50000...
# Encoding document 5030/50000...
# Encoding document 5031/50000...
# Encoding document 5032/50000...
# Encoding document 5033/50000...
# Encoding document 5034/50000...
# Encoding document 5035/50000...
# Encoding document 5036/50000...
# Encoding document 5037/50000...
# Encoding document 5038/50000...
# Encoding document 5039/50000...
# Encoding document 5040/50000...
# Encoding document 5041/50000...
# Encoding document 5042/50000...
# Encoding document 5043/50000...
# Encoding document 5044/50000...
# Encoding document 5045/50000...
# Encoding document 5046/50000...
# Encoding document 5047/50000...
# Encoding document 5048/50000...
# Encoding document 5049/50000...
# Encoding document 5050/50000...
# Encoding document 5051/50000...
# Encoding document 5052/50000...
# Encoding document 5053/50000...
# Encoding document 5054/50000...
# Encoding document 5055/50000...
# Encoding document 5056/50000...
# Encoding document 5057/50000...
# Encoding document 5058/50000...
# Encoding document 5059/50000...
# Encoding document 5060/50000...
# Encoding document 5061/50000...
# Encoding document 5062/50000...
# Encoding document 5063/50000...
# Encoding document 5064/50000...
# Encoding document 5065/50000...
# Encoding document 5066/50000...
# Encoding document 5067/50000...
# Encoding document 5068/50000...
# Encoding document 5069/50000...
# Encoding document 5070/50000...
# Encoding document 5071/50000...
# Encoding document 5072/50000...
# Encoding document 5073/50000...
# Encoding document 5074/50000...
# Encoding document 5075/50000...
# Encoding document 5076/50000...
# Encoding document 5077/50000...
# Encoding document 5078/50000...
# Encoding document 5079/50000...
# Encoding document 5080/50000...
# Encoding document 5081/50000...
# Encoding document 5082/50000...
# Encoding document 5083/50000...
# Encoding document 5084/50000...
# Encoding document 5085/50000...
# Encoding document 5086/50000...
# Encoding document 5087/50000...
# Encoding document 5088/50000...
# Encoding document 5089/50000...
# Encoding document 5090/50000...
# Encoding document 5091/50000...
# Encoding document 5092/50000...
# Encoding document 5093/50000...
# Encoding document 5094/50000...
# Encoding document 5095/50000...
# Encoding document 5096/50000...
# Encoding document 5097/50000...
# Encoding document 5098/50000...
# Encoding document 5099/50000...
# Encoding document 5100/50000...
# Encoding document 5101/50000...
# Encoding document 5102/50000...
# Encoding document 5103/50000...
# Encoding document 5104/50000...
# Encoding document 5105/50000...
# Encoding document 5106/50000...
# Encoding document 5107/50000...
# Encoding document 5108/50000...
# Encoding document 5109/50000...
# Encoding document 5110/50000...
# Encoding document 5111/50000...
# Encoding document 5112/50000...
# Encoding document 5113/50000...
# Encoding document 5114/50000...
# Encoding document 5115/50000...
# Encoding document 5116/50000...
# Encoding document 5117/50000...
# Encoding document 5118/50000...
# Encoding document 5119/50000...
# Encoding document 5120/50000...
# Encoding document 5121/50000...
# Encoding document 5122/50000...
# Encoding document 5123/50000...
# Encoding document 5124/50000...
# Encoding document 5125/50000...
# Encoding document 5126/50000...
# Encoding document 5127/50000...
# Encoding document 5128/50000...
# Encoding document 5129/50000...
# Encoding document 5130/50000...
# Encoding document 5131/50000...
# Encoding document 5132/50000...
# Encoding document 5133/50000...
# Encoding document 5134/50000...
# Encoding document 5135/50000...
# Encoding document 5136/50000...
# Encoding document 5137/50000...
# Encoding document 5138/50000...
# Encoding document 5139/50000...
# Encoding document 5140/50000...
# Encoding document 5141/50000...
# Encoding document 5142/50000...
# Encoding document 5143/50000...
# Encoding document 5144/50000...
# Encoding document 5145/50000...
# Encoding document 5146/50000...
# Encoding document 5147/50000...
# Encoding document 5148/50000...
# Encoding document 5149/50000...
# Encoding document 5150/50000...
# Encoding document 5151/50000...
# Encoding document 5152/50000...
# Encoding document 5153/50000...
# Encoding document 5154/50000...
# Encoding document 5155/50000...
# Encoding document 5156/50000...
# Encoding document 5157/50000...
# Encoding document 5158/50000...
# Encoding document 5159/50000...
# Encoding document 5160/50000...
# Encoding document 5161/50000...
# Encoding document 5162/50000...
# Encoding document 5163/50000...
# Encoding document 5164/50000...
# Encoding document 5165/50000...
# Encoding document 5166/50000...
# Encoding document 5167/50000...
# Encoding document 5168/50000...
# Encoding document 5169/50000...
# Encoding document 5170/50000...
# Encoding document 5171/50000...
# Encoding document 5172/50000...
# Encoding document 5173/50000...
# Encoding document 5174/50000...
# Encoding document 5175/50000...
# Encoding document 5176/50000...
# Encoding document 5177/50000...
# Encoding document 5178/50000...
# Encoding document 5179/50000...
# Encoding document 5180/50000...
# Encoding document 5181/50000...
# Encoding document 5182/50000...
# Encoding document 5183/50000...
# Encoding document 5184/50000...
# Encoding document 5185/50000...
# Encoding document 5186/50000...
# Encoding document 5187/50000...
# Encoding document 5188/50000...
# Encoding document 5189/50000...
# Encoding document 5190/50000...
# Encoding document 5191/50000...
# Encoding document 5192/50000...
# Encoding document 5193/50000...
# Encoding document 5194/50000...
# Encoding document 5195/50000...
# Encoding document 5196/50000...
# Encoding document 5197/50000...
# Encoding document 5198/50000...
# Encoding document 5199/50000...
# Encoding document 5200/50000...
# Encoding document 5201/50000...
# Encoding document 5202/50000...
# Encoding document 5203/50000...
# Encoding document 5204/50000...
# Encoding document 5205/50000...
# Encoding document 5206/50000...
# Encoding document 5207/50000...
# Encoding document 5208/50000...
# Encoding document 5209/50000...
# Encoding document 5210/50000...
# Encoding document 5211/50000...
# Encoding document 5212/50000...
# Encoding document 5213/50000...
# Encoding document 5214/50000...
# Encoding document 5215/50000...
# Encoding document 5216/50000...
# Encoding document 5217/50000...
# Encoding document 5218/50000...
# Encoding document 5219/50000...
# Encoding document 5220/50000...
# Encoding document 5221/50000...
# Encoding document 5222/50000...
# Encoding document 5223/50000...
# Encoding document 5224/50000...
# Encoding document 5225/50000...
# Encoding document 5226/50000...
# Encoding document 5227/50000...
# Encoding document 5228/50000...
# Encoding document 5229/50000...
# Encoding document 5230/50000...
# Encoding document 5231/50000...
# Encoding document 5232/50000...
# Encoding document 5233/50000...
# Encoding document 5234/50000...
# Encoding document 5235/50000...
# Encoding document 5236/50000...
# Encoding document 5237/50000...
# Encoding document 5238/50000...
# Encoding document 5239/50000...
# Encoding document 5240/50000...
# Encoding document 5241/50000...
# Encoding document 5242/50000...
# Encoding document 5243/50000...
# Encoding document 5244/50000...
# Encoding document 5245/50000...
# Encoding document 5246/50000...
# Encoding document 5247/50000...
# Encoding document 5248/50000...
# Encoding document 5249/50000...
# Encoding document 5250/50000...
# Encoding document 5251/50000...
# Encoding document 5252/50000...
# Encoding document 5253/50000...
# Encoding document 5254/50000...
# Encoding document 5255/50000...
# Encoding document 5256/50000...
# Encoding document 5257/50000...
# Encoding document 5258/50000...
# Encoding document 5259/50000...
# Encoding document 5260/50000...
# Encoding document 5261/50000...
# Encoding document 5262/50000...
# Encoding document 5263/50000...
# Encoding document 5264/50000...
# Encoding document 5265/50000...
# Encoding document 5266/50000...
# Encoding document 5267/50000...
# Encoding document 5268/50000...
# Encoding document 5269/50000...
# Encoding document 5270/50000...
# Encoding document 5271/50000...
# Encoding document 5272/50000...
# Encoding document 5273/50000...
# Encoding document 5274/50000...
# Encoding document 5275/50000...
# Encoding document 5276/50000...
# Encoding document 5277/50000...
# Encoding document 5278/50000...
# Encoding document 5279/50000...
# Encoding document 5280/50000...
# Encoding document 5281/50000...
# Encoding document 5282/50000...
# Encoding document 5283/50000...
# Encoding document 5284/50000...
# Encoding document 5285/50000...
# Encoding document 5286/50000...
# Encoding document 5287/50000...
# Encoding document 5288/50000...
# Encoding document 5289/50000...
# Encoding document 5290/50000...
# Encoding document 5291/50000...
# Encoding document 5292/50000...
# Encoding document 5293/50000...
# Encoding document 5294/50000...
# Encoding document 5295/50000...
# Encoding document 5296/50000...
# Encoding document 5297/50000...
# Encoding document 5298/50000...
# Encoding document 5299/50000...
# Encoding document 5300/50000...
# Encoding document 5301/50000...
# Encoding document 5302/50000...
# Encoding document 5303/50000...
# Encoding document 5304/50000...
# Encoding document 5305/50000...
# Encoding document 5306/50000...
# Encoding document 5307/50000...
# Encoding document 5308/50000...
# Encoding document 5309/50000...
# Encoding document 5310/50000...
# Encoding document 5311/50000...
# Encoding document 5312/50000...
# Encoding document 5313/50000...
# Encoding document 5314/50000...
# Encoding document 5315/50000...
# Encoding document 5316/50000...
# Encoding document 5317/50000...
# Encoding document 5318/50000...
# Encoding document 5319/50000...
# Encoding document 5320/50000...
# Encoding document 5321/50000...
# Encoding document 5322/50000...
# Encoding document 5323/50000...
# Encoding document 5324/50000...
# Encoding document 5325/50000...
# Encoding document 5326/50000...
# Encoding document 5327/50000...
# Encoding document 5328/50000...
# Encoding document 5329/50000...
# Encoding document 5330/50000...
# Encoding document 5331/50000...
# Encoding document 5332/50000...
# Encoding document 5333/50000...
# Encoding document 5334/50000...
# Encoding document 5335/50000...
# Encoding document 5336/50000...
# Encoding document 5337/50000...
# Encoding document 5338/50000...
# Encoding document 5339/50000...
# Encoding document 5340/50000...
# Encoding document 5341/50000...
# Encoding document 5342/50000...
# Encoding document 5343/50000...
# Encoding document 5344/50000...
# Encoding document 5345/50000...
# Encoding document 5346/50000...
# Encoding document 5347/50000...
# Encoding document 5348/50000...
# Encoding document 5349/50000...
# Encoding document 5350/50000...
# Encoding document 5351/50000...
# Encoding document 5352/50000...
# Encoding document 5353/50000...
# Encoding document 5354/50000...
# Encoding document 5355/50000...
# Encoding document 5356/50000...
# Encoding document 5357/50000...
# Encoding document 5358/50000...
# Encoding document 5359/50000...
# Encoding document 5360/50000...
# Encoding document 5361/50000...
# Encoding document 5362/50000...
# Encoding document 5363/50000...
# Encoding document 5364/50000...
# Encoding document 5365/50000...
# Encoding document 5366/50000...
# Encoding document 5367/50000...
# Encoding document 5368/50000...
# Encoding document 5369/50000...
# Encoding document 5370/50000...
# Encoding document 5371/50000...
# Encoding document 5372/50000...
# Encoding document 5373/50000...
# Encoding document 5374/50000...
# Encoding document 5375/50000...
# Encoding document 5376/50000...
# Encoding document 5377/50000...
# Encoding document 5378/50000...
# Encoding document 5379/50000...
# Encoding document 5380/50000...
# Encoding document 5381/50000...
# Encoding document 5382/50000...
# Encoding document 5383/50000...
# Encoding document 5384/50000...
# Encoding document 5385/50000...
# Encoding document 5386/50000...
# Encoding document 5387/50000...
# Encoding document 5388/50000...
# Encoding document 5389/50000...
# Encoding document 5390/50000...
# Encoding document 5391/50000...
# Encoding document 5392/50000...
# Encoding document 5393/50000...
# Encoding document 5394/50000...
# Encoding document 5395/50000...
# Encoding document 5396/50000...
# Encoding document 5397/50000...
# Encoding document 5398/50000...
# Encoding document 5399/50000...
# Encoding document 5400/50000...
# Encoding document 5401/50000...
# Encoding document 5402/50000...
# Encoding document 5403/50000...
# Encoding document 5404/50000...
# Encoding document 5405/50000...
# Encoding document 5406/50000...
# Encoding document 5407/50000...
# Encoding document 5408/50000...
# Encoding document 5409/50000...
# Encoding document 5410/50000...
# Encoding document 5411/50000...
# Encoding document 5412/50000...
# Encoding document 5413/50000...
# Encoding document 5414/50000...
# Encoding document 5415/50000...
# Encoding document 5416/50000...
# Encoding document 5417/50000...
# Encoding document 5418/50000...
# Encoding document 5419/50000...
# Encoding document 5420/50000...
# Encoding document 5421/50000...
# Encoding document 5422/50000...
# Encoding document 5423/50000...
# Encoding document 5424/50000...
# Encoding document 5425/50000...
# Encoding document 5426/50000...
# Encoding document 5427/50000...
# Encoding document 5428/50000...
# Encoding document 5429/50000...
# Encoding document 5430/50000...
# Encoding document 5431/50000...
# Encoding document 5432/50000...
# Encoding document 5433/50000...
# Encoding document 5434/50000...
# Encoding document 5435/50000...
# Encoding document 5436/50000...
# Encoding document 5437/50000...
# Encoding document 5438/50000...
# Encoding document 5439/50000...
# Encoding document 5440/50000...
# Encoding document 5441/50000...
# Encoding document 5442/50000...
# Encoding document 5443/50000...
# Encoding document 5444/50000...
# Encoding document 5445/50000...
# Encoding document 5446/50000...
# Encoding document 5447/50000...
# Encoding document 5448/50000...
# Encoding document 5449/50000...
# Encoding document 5450/50000...
# Encoding document 5451/50000...
# Encoding document 5452/50000...
# Encoding document 5453/50000...
# Encoding document 5454/50000...
# Encoding document 5455/50000...
# Encoding document 5456/50000...
# Encoding document 5457/50000...
# Encoding document 5458/50000...
# Encoding document 5459/50000...
# Encoding document 5460/50000...
# Encoding document 5461/50000...
# Encoding document 5462/50000...
# Encoding document 5463/50000...
# Encoding document 5464/50000...
# Encoding document 5465/50000...
# Encoding document 5466/50000...
# Encoding document 5467/50000...
# Encoding document 5468/50000...
# Encoding document 5469/50000...
# Encoding document 5470/50000...
# Encoding document 5471/50000...
# Encoding document 5472/50000...
# Encoding document 5473/50000...
# Encoding document 5474/50000...
# Encoding document 5475/50000...
# Encoding document 5476/50000...
# Encoding document 5477/50000...
# Encoding document 5478/50000...
# Encoding document 5479/50000...
# Encoding document 5480/50000...
# Encoding document 5481/50000...
# Encoding document 5482/50000...
# Encoding document 5483/50000...
# Encoding document 5484/50000...
# Encoding document 5485/50000...
# Encoding document 5486/50000...
# Encoding document 5487/50000...
# Encoding document 5488/50000...
# Encoding document 5489/50000...
# Encoding document 5490/50000...
# Encoding document 5491/50000...
# Encoding document 5492/50000...
# Encoding document 5493/50000...
# Encoding document 5494/50000...
# Encoding document 5495/50000...
# Encoding document 5496/50000...
# Encoding document 5497/50000...
# Encoding document 5498/50000...
# Encoding document 5499/50000...
# Encoding document 5500/50000...
# Encoding document 5501/50000...
# Encoding document 5502/50000...
# Encoding document 5503/50000...
# Encoding document 5504/50000...
# Encoding document 5505/50000...
# Encoding document 5506/50000...
# Encoding document 5507/50000...
# Encoding document 5508/50000...
# Encoding document 5509/50000...
# Encoding document 5510/50000...
# Encoding document 5511/50000...
# Encoding document 5512/50000...
# Encoding document 5513/50000...
# Encoding document 5514/50000...
# Encoding document 5515/50000...
# Encoding document 5516/50000...
# Encoding document 5517/50000...
# Encoding document 5518/50000...
# Encoding document 5519/50000...
# Encoding document 5520/50000...
# Encoding document 5521/50000...
# Encoding document 5522/50000...
# Encoding document 5523/50000...
# Encoding document 5524/50000...
# Encoding document 5525/50000...
# Encoding document 5526/50000...
# Encoding document 5527/50000...
# Encoding document 5528/50000...
# Encoding document 5529/50000...
# Encoding document 5530/50000...
# Encoding document 5531/50000...
# Encoding document 5532/50000...
# Encoding document 5533/50000...
# Encoding document 5534/50000...
# Encoding document 5535/50000...
# Encoding document 5536/50000...
# Encoding document 5537/50000...
# Encoding document 5538/50000...
# Encoding document 5539/50000...
# Encoding document 5540/50000...
# Encoding document 5541/50000...
# Encoding document 5542/50000...
# Encoding document 5543/50000...
# Encoding document 5544/50000...
# Encoding document 5545/50000...
# Encoding document 5546/50000...
# Encoding document 5547/50000...
# Encoding document 5548/50000...
# Encoding document 5549/50000...
# Encoding document 5550/50000...
# Encoding document 5551/50000...
# Encoding document 5552/50000...
# Encoding document 5553/50000...
# Encoding document 5554/50000...
# Encoding document 5555/50000...
# Encoding document 5556/50000...
# Encoding document 5557/50000...
# Encoding document 5558/50000...
# Encoding document 5559/50000...
# Encoding document 5560/50000...
# Encoding document 5561/50000...
# Encoding document 5562/50000...
# Encoding document 5563/50000...
# Encoding document 5564/50000...
# Encoding document 5565/50000...
# Encoding document 5566/50000...
# Encoding document 5567/50000...
# Encoding document 5568/50000...
# Encoding document 5569/50000...
# Encoding document 5570/50000...
# Encoding document 5571/50000...
# Encoding document 5572/50000...
# Encoding document 5573/50000...
# Encoding document 5574/50000...
# Encoding document 5575/50000...
# Encoding document 5576/50000...
# Encoding document 5577/50000...
# Encoding document 5578/50000...
# Encoding document 5579/50000...
# Encoding document 5580/50000...
# Encoding document 5581/50000...
# Encoding document 5582/50000...
# Encoding document 5583/50000...
# Encoding document 5584/50000...
# Encoding document 5585/50000...
# Encoding document 5586/50000...
# Encoding document 5587/50000...
# Encoding document 5588/50000...
# Encoding document 5589/50000...
# Encoding document 5590/50000...
# Encoding document 5591/50000...
# Encoding document 5592/50000...
# Encoding document 5593/50000...
# Encoding document 5594/50000...
# Encoding document 5595/50000...
# Encoding document 5596/50000...
# Encoding document 5597/50000...
# Encoding document 5598/50000...
# Encoding document 5599/50000...
# Encoding document 5600/50000...
# Encoding document 5601/50000...
# Encoding document 5602/50000...
# Encoding document 5603/50000...
# Encoding document 5604/50000...
# Encoding document 5605/50000...
# Encoding document 5606/50000...
# Encoding document 5607/50000...
# Encoding document 5608/50000...
# Encoding document 5609/50000...
# Encoding document 5610/50000...
# Encoding document 5611/50000...
# Encoding document 5612/50000...
# Encoding document 5613/50000...
# Encoding document 5614/50000...
# Encoding document 5615/50000...
# Encoding document 5616/50000...
# Encoding document 5617/50000...
# Encoding document 5618/50000...
# Encoding document 5619/50000...
# Encoding document 5620/50000...
# Encoding document 5621/50000...
# Encoding document 5622/50000...
# Encoding document 5623/50000...
# Encoding document 5624/50000...
# Encoding document 5625/50000...
# Encoding document 5626/50000...
# Encoding document 5627/50000...
# Encoding document 5628/50000...
# Encoding document 5629/50000...
# Encoding document 5630/50000...
# Encoding document 5631/50000...
# Encoding document 5632/50000...
# Encoding document 5633/50000...
# Encoding document 5634/50000...
# Encoding document 5635/50000...
# Encoding document 5636/50000...
# Encoding document 5637/50000...
# Encoding document 5638/50000...
# Encoding document 5639/50000...
# Encoding document 5640/50000...
# Encoding document 5641/50000...
# Encoding document 5642/50000...
# Encoding document 5643/50000...
# Encoding document 5644/50000...
# Encoding document 5645/50000...
# Encoding document 5646/50000...
# Encoding document 5647/50000...
# Encoding document 5648/50000...
# Encoding document 5649/50000...
# Encoding document 5650/50000...
# Encoding document 5651/50000...
# Encoding document 5652/50000...
# Encoding document 5653/50000...
# Encoding document 5654/50000...
# Encoding document 5655/50000...
# Encoding document 5656/50000...
# Encoding document 5657/50000...
# Encoding document 5658/50000...
# Encoding document 5659/50000...
# Encoding document 5660/50000...
# Encoding document 5661/50000...
# Encoding document 5662/50000...
# Encoding document 5663/50000...
# Encoding document 5664/50000...
# Encoding document 5665/50000...
# Encoding document 5666/50000...
# Encoding document 5667/50000...
# Encoding document 5668/50000...
# Encoding document 5669/50000...
# Encoding document 5670/50000...
# Encoding document 5671/50000...
# Encoding document 5672/50000...
# Encoding document 5673/50000...
# Encoding document 5674/50000...
# Encoding document 5675/50000...
# Encoding document 5676/50000...
# Encoding document 5677/50000...
# Encoding document 5678/50000...
# Encoding document 5679/50000...
# Encoding document 5680/50000...
# Encoding document 5681/50000...
# Encoding document 5682/50000...
# Encoding document 5683/50000...
# Encoding document 5684/50000...
# Encoding document 5685/50000...
# Encoding document 5686/50000...
# Encoding document 5687/50000...
# Encoding document 5688/50000...
# Encoding document 5689/50000...
# Encoding document 5690/50000...
# Encoding document 5691/50000...
# Encoding document 5692/50000...
# Encoding document 5693/50000...
# Encoding document 5694/50000...
# Encoding document 5695/50000...
# Encoding document 5696/50000...
# Encoding document 5697/50000...
# Encoding document 5698/50000...
# Encoding document 5699/50000...
# Encoding document 5700/50000...
# Encoding document 5701/50000...
# Encoding document 5702/50000...
# Encoding document 5703/50000...
# Encoding document 5704/50000...
# Encoding document 5705/50000...
# Encoding document 5706/50000...
# Encoding document 5707/50000...
# Encoding document 5708/50000...
# Encoding document 5709/50000...
# Encoding document 5710/50000...
# Encoding document 5711/50000...
# Encoding document 5712/50000...
# Encoding document 5713/50000...
# Encoding document 5714/50000...
# Encoding document 5715/50000...
# Encoding document 5716/50000...
# Encoding document 5717/50000...
# Encoding document 5718/50000...
# Encoding document 5719/50000...
# Encoding document 5720/50000...
# Encoding document 5721/50000...
# Encoding document 5722/50000...
# Encoding document 5723/50000...
# Encoding document 5724/50000...
# Encoding document 5725/50000...
# Encoding document 5726/50000...
# Encoding document 5727/50000...
# Encoding document 5728/50000...
# Encoding document 5729/50000...
# Encoding document 5730/50000...
# Encoding document 5731/50000...
# Encoding document 5732/50000...
# Encoding document 5733/50000...
# Encoding document 5734/50000...
# Encoding document 5735/50000...
# Encoding document 5736/50000...
# Encoding document 5737/50000...
# Encoding document 5738/50000...
# Encoding document 5739/50000...
# Encoding document 5740/50000...
# Encoding document 5741/50000...
# Encoding document 5742/50000...
# Encoding document 5743/50000...
# Encoding document 5744/50000...
# Encoding document 5745/50000...
# Encoding document 5746/50000...
# Encoding document 5747/50000...
# Encoding document 5748/50000...
# Encoding document 5749/50000...
# Encoding document 5750/50000...
# Encoding document 5751/50000...
# Encoding document 5752/50000...
# Encoding document 5753/50000...
# Encoding document 5754/50000...
# Encoding document 5755/50000...
# Encoding document 5756/50000...
# Encoding document 5757/50000...
# Encoding document 5758/50000...
# Encoding document 5759/50000...
# Encoding document 5760/50000...
# Encoding document 5761/50000...
# Encoding document 5762/50000...
# Encoding document 5763/50000...
# Encoding document 5764/50000...
# Encoding document 5765/50000...
# Encoding document 5766/50000...
# Encoding document 5767/50000...
# Encoding document 5768/50000...
# Encoding document 5769/50000...
# Encoding document 5770/50000...
# Encoding document 5771/50000...
# Encoding document 5772/50000...
# Encoding document 5773/50000...
# Encoding document 5774/50000...
# Encoding document 5775/50000...
# Encoding document 5776/50000...
# Encoding document 5777/50000...
# Encoding document 5778/50000...
# Encoding document 5779/50000...
# Encoding document 5780/50000...
# Encoding document 5781/50000...
# Encoding document 5782/50000...
# Encoding document 5783/50000...
# Encoding document 5784/50000...
# Encoding document 5785/50000...
# Encoding document 5786/50000...
# Encoding document 5787/50000...
# Encoding document 5788/50000...
# Encoding document 5789/50000...
# Encoding document 5790/50000...
# Encoding document 5791/50000...
# Encoding document 5792/50000...
# Encoding document 5793/50000...
# Encoding document 5794/50000...
# Encoding document 5795/50000...
# Encoding document 5796/50000...
# Encoding document 5797/50000...
# Encoding document 5798/50000...
# Encoding document 5799/50000...
# Encoding document 5800/50000...
# Encoding document 5801/50000...
# Encoding document 5802/50000...
# Encoding document 5803/50000...
# Encoding document 5804/50000...
# Encoding document 5805/50000...
# Encoding document 5806/50000...
# Encoding document 5807/50000...
# Encoding document 5808/50000...
# Encoding document 5809/50000...
# Encoding document 5810/50000...
# Encoding document 5811/50000...
# Encoding document 5812/50000...
# Encoding document 5813/50000...
# Encoding document 5814/50000...
# Encoding document 5815/50000...
# Encoding document 5816/50000...
# Encoding document 5817/50000...
# Encoding document 5818/50000...
# Encoding document 5819/50000...
# Encoding document 5820/50000...
# Encoding document 5821/50000...
# Encoding document 5822/50000...
# Encoding document 5823/50000...
# Encoding document 5824/50000...
# Encoding document 5825/50000...
# Encoding document 5826/50000...
# Encoding document 5827/50000...
# Encoding document 5828/50000...
# Encoding document 5829/50000...
# Encoding document 5830/50000...
# Encoding document 5831/50000...
# Encoding document 5832/50000...
# Encoding document 5833/50000...
# Encoding document 5834/50000...
# Encoding document 5835/50000...
# Encoding document 5836/50000...
# Encoding document 5837/50000...
# Encoding document 5838/50000...
# Encoding document 5839/50000...
# Encoding document 5840/50000...
# Encoding document 5841/50000...
# Encoding document 5842/50000...
# Encoding document 5843/50000...
# Encoding document 5844/50000...
# Encoding document 5845/50000...
# Encoding document 5846/50000...
# Encoding document 5847/50000...
# Encoding document 5848/50000...
# Encoding document 5849/50000...
# Encoding document 5850/50000...
# Encoding document 5851/50000...
# Encoding document 5852/50000...
# Encoding document 5853/50000...
# Encoding document 5854/50000...
# Encoding document 5855/50000...
# Encoding document 5856/50000...
# Encoding document 5857/50000...
# Encoding document 5858/50000...
# Encoding document 5859/50000...
# Encoding document 5860/50000...
# Encoding document 5861/50000...
# Encoding document 5862/50000...
# Encoding document 5863/50000...
# Encoding document 5864/50000...
# Encoding document 5865/50000...
# Encoding document 5866/50000...
# Encoding document 5867/50000...
# Encoding document 5868/50000...
# Encoding document 5869/50000...
# Encoding document 5870/50000...
# Encoding document 5871/50000...
# Encoding document 5872/50000...
# Encoding document 5873/50000...
# Encoding document 5874/50000...
# Encoding document 5875/50000...
# Encoding document 5876/50000...
# Encoding document 5877/50000...
# Encoding document 5878/50000...
# Encoding document 5879/50000...
# Encoding document 5880/50000...
# Encoding document 5881/50000...
# Encoding document 5882/50000...
# Encoding document 5883/50000...
# Encoding document 5884/50000...
# Encoding document 5885/50000...
# Encoding document 5886/50000...
# Encoding document 5887/50000...
# Encoding document 5888/50000...
# Encoding document 5889/50000...
# Encoding document 5890/50000...
# Encoding document 5891/50000...
# Encoding document 5892/50000...
# Encoding document 5893/50000...
# Encoding document 5894/50000...
# Encoding document 5895/50000...
# Encoding document 5896/50000...
# Encoding document 5897/50000...
# Encoding document 5898/50000...
# Encoding document 5899/50000...
# Encoding document 5900/50000...
# Encoding document 5901/50000...
# Encoding document 5902/50000...
# Encoding document 5903/50000...
# Encoding document 5904/50000...
# Encoding document 5905/50000...
# Encoding document 5906/50000...
# Encoding document 5907/50000...
# Encoding document 5908/50000...
# Encoding document 5909/50000...
# Encoding document 5910/50000...
# Encoding document 5911/50000...
# Encoding document 5912/50000...
# Encoding document 5913/50000...
# Encoding document 5914/50000...
# Encoding document 5915/50000...
# Encoding document 5916/50000...
# Encoding document 5917/50000...
# Encoding document 5918/50000...
# Encoding document 5919/50000...
# Encoding document 5920/50000...
# Encoding document 5921/50000...
# Encoding document 5922/50000...
# Encoding document 5923/50000...
# Encoding document 5924/50000...
# Encoding document 5925/50000...
# Encoding document 5926/50000...
# Encoding document 5927/50000...
# Encoding document 5928/50000...
# Encoding document 5929/50000...
# Encoding document 5930/50000...
# Encoding document 5931/50000...
# Encoding document 5932/50000...
# Encoding document 5933/50000...
# Encoding document 5934/50000...
# Encoding document 5935/50000...
# Encoding document 5936/50000...
# Encoding document 5937/50000...
# Encoding document 5938/50000...
# Encoding document 5939/50000...
# Encoding document 5940/50000...
# Encoding document 5941/50000...
# Encoding document 5942/50000...
# Encoding document 5943/50000...
# Encoding document 5944/50000...
# Encoding document 5945/50000...
# Encoding document 5946/50000...
# Encoding document 5947/50000...
# Encoding document 5948/50000...
# Encoding document 5949/50000...
# Encoding document 5950/50000...
# Encoding document 5951/50000...
# Encoding document 5952/50000...
# Encoding document 5953/50000...
# Encoding document 5954/50000...
# Encoding document 5955/50000...
# Encoding document 5956/50000...
# Encoding document 5957/50000...
# Encoding document 5958/50000...
# Encoding document 5959/50000...
# Encoding document 5960/50000...
# Encoding document 5961/50000...
# Encoding document 5962/50000...
# Encoding document 5963/50000...
# Encoding document 5964/50000...
# Encoding document 5965/50000...
# Encoding document 5966/50000...
# Encoding document 5967/50000...
# Encoding document 5968/50000...
# Encoding document 5969/50000...
# Encoding document 5970/50000...
# Encoding document 5971/50000...
# Encoding document 5972/50000...
# Encoding document 5973/50000...
# Encoding document 5974/50000...
# Encoding document 5975/50000...
# Encoding document 5976/50000...
# Encoding document 5977/50000...
# Encoding document 5978/50000...
# Encoding document 5979/50000...
# Encoding document 5980/50000...
# Encoding document 5981/50000...
# Encoding document 5982/50000...
# Encoding document 5983/50000...
# Encoding document 5984/50000...
# Encoding document 5985/50000...
# Encoding document 5986/50000...
# Encoding document 5987/50000...
# Encoding document 5988/50000...
# Encoding document 5989/50000...
# Encoding document 5990/50000...
# Encoding document 5991/50000...
# Encoding document 5992/50000...
# Encoding document 5993/50000...
# Encoding document 5994/50000...
# Encoding document 5995/50000...
# Encoding document 5996/50000...
# Encoding document 5997/50000...
# Encoding document 5998/50000...
# Encoding document 5999/50000...
# Encoding document 6000/50000...
# Encoding document 6001/50000...
# Encoding document 6002/50000...
# Encoding document 6003/50000...
# Encoding document 6004/50000...
# Encoding document 6005/50000...
# Encoding document 6006/50000...
# Encoding document 6007/50000...
# Encoding document 6008/50000...
# Encoding document 6009/50000...
# Encoding document 6010/50000...
# Encoding document 6011/50000...
# Encoding document 6012/50000...
# Encoding document 6013/50000...
# Encoding document 6014/50000...
# Encoding document 6015/50000...
# Encoding document 6016/50000...
# Encoding document 6017/50000...
# Encoding document 6018/50000...
# Encoding document 6019/50000...
# Encoding document 6020/50000...
# Encoding document 6021/50000...
# Encoding document 6022/50000...
# Encoding document 6023/50000...
# Encoding document 6024/50000...
# Encoding document 6025/50000...
# Encoding document 6026/50000...
# Encoding document 6027/50000...
# Encoding document 6028/50000...
# Encoding document 6029/50000...
# Encoding document 6030/50000...
# Encoding document 6031/50000...
# Encoding document 6032/50000...
# Encoding document 6033/50000...
# Encoding document 6034/50000...
# Encoding document 6035/50000...
# Encoding document 6036/50000...
# Encoding document 6037/50000...
# Encoding document 6038/50000...
# Encoding document 6039/50000...
# Encoding document 6040/50000...
# Encoding document 6041/50000...
# Encoding document 6042/50000...
# Encoding document 6043/50000...
# Encoding document 6044/50000...
# Encoding document 6045/50000...
# Encoding document 6046/50000...
# Encoding document 6047/50000...
# Encoding document 6048/50000...
# Encoding document 6049/50000...
# Encoding document 6050/50000...
# Encoding document 6051/50000...
# Encoding document 6052/50000...
# Encoding document 6053/50000...
# Encoding document 6054/50000...
# Encoding document 6055/50000...
# Encoding document 6056/50000...
# Encoding document 6057/50000...
# Encoding document 6058/50000...
# Encoding document 6059/50000...
# Encoding document 6060/50000...
# Encoding document 6061/50000...
# Encoding document 6062/50000...
# Encoding document 6063/50000...
# Encoding document 6064/50000...
# Encoding document 6065/50000...
# Encoding document 6066/50000...
# Encoding document 6067/50000...
# Encoding document 6068/50000...
# Encoding document 6069/50000...
# Encoding document 6070/50000...
# Encoding document 6071/50000...
# Encoding document 6072/50000...
# Encoding document 6073/50000...
# Encoding document 6074/50000...
# Encoding document 6075/50000...
# Encoding document 6076/50000...
# Encoding document 6077/50000...
# Encoding document 6078/50000...
# Encoding document 6079/50000...
# Encoding document 6080/50000...
# Encoding document 6081/50000...
# Encoding document 6082/50000...
# Encoding document 6083/50000...
# Encoding document 6084/50000...
# Encoding document 6085/50000...
# Encoding document 6086/50000...
# Encoding document 6087/50000...
# Encoding document 6088/50000...
# Encoding document 6089/50000...
# Encoding document 6090/50000...
# Encoding document 6091/50000...
# Encoding document 6092/50000...
# Encoding document 6093/50000...
# Encoding document 6094/50000...
# Encoding document 6095/50000...
# Encoding document 6096/50000...
# Encoding document 6097/50000...
# Encoding document 6098/50000...
# Encoding document 6099/50000...
# Encoding document 6100/50000...
# Encoding document 6101/50000...
# Encoding document 6102/50000...
# Encoding document 6103/50000...
# Encoding document 6104/50000...
# Encoding document 6105/50000...
# Encoding document 6106/50000...
# Encoding document 6107/50000...
# Encoding document 6108/50000...
# Encoding document 6109/50000...
# Encoding document 6110/50000...
# Encoding document 6111/50000...
# Encoding document 6112/50000...
# Encoding document 6113/50000...
# Encoding document 6114/50000...
# Encoding document 6115/50000...
# Encoding document 6116/50000...
# Encoding document 6117/50000...
# Encoding document 6118/50000...
# Encoding document 6119/50000...
# Encoding document 6120/50000...
# Encoding document 6121/50000...
# Encoding document 6122/50000...
# Encoding document 6123/50000...
# Encoding document 6124/50000...
# Encoding document 6125/50000...
# Encoding document 6126/50000...
# Encoding document 6127/50000...
# Encoding document 6128/50000...
# Encoding document 6129/50000...
# Encoding document 6130/50000...
# Encoding document 6131/50000...
# Encoding document 6132/50000...
# Encoding document 6133/50000...
# Encoding document 6134/50000...
# Encoding document 6135/50000...
# Encoding document 6136/50000...
# Encoding document 6137/50000...
# Encoding document 6138/50000...
# Encoding document 6139/50000...
# Encoding document 6140/50000...
# Encoding document 6141/50000...
# Encoding document 6142/50000...
# Encoding document 6143/50000...
# Encoding document 6144/50000...
# Encoding document 6145/50000...
# Encoding document 6146/50000...
# Encoding document 6147/50000...
# Encoding document 6148/50000...
# Encoding document 6149/50000...
# Encoding document 6150/50000...
# Encoding document 6151/50000...
# Encoding document 6152/50000...
# Encoding document 6153/50000...
# Encoding document 6154/50000...
# Encoding document 6155/50000...
# Encoding document 6156/50000...
# Encoding document 6157/50000...
# Encoding document 6158/50000...
# Encoding document 6159/50000...
# Encoding document 6160/50000...
# Encoding document 6161/50000...
# Encoding document 6162/50000...
# Encoding document 6163/50000...
# Encoding document 6164/50000...
# Encoding document 6165/50000...
# Encoding document 6166/50000...
# Encoding document 6167/50000...
# Encoding document 6168/50000...
# Encoding document 6169/50000...
# Encoding document 6170/50000...
# Encoding document 6171/50000...
# Encoding document 6172/50000...
# Encoding document 6173/50000...
# Encoding document 6174/50000...
# Encoding document 6175/50000...
# Encoding document 6176/50000...
# Encoding document 6177/50000...
# Encoding document 6178/50000...
# Encoding document 6179/50000...
# Encoding document 6180/50000...
# Encoding document 6181/50000...
# Encoding document 6182/50000...
# Encoding document 6183/50000...
# Encoding document 6184/50000...
# Encoding document 6185/50000...
# Encoding document 6186/50000...
# Encoding document 6187/50000...
# Encoding document 6188/50000...
# Encoding document 6189/50000...
# Encoding document 6190/50000...
# Encoding document 6191/50000...
# Encoding document 6192/50000...
# Encoding document 6193/50000...
# Encoding document 6194/50000...
# Encoding document 6195/50000...
# Encoding document 6196/50000...
# Encoding document 6197/50000...
# Encoding document 6198/50000...
# Encoding document 6199/50000...
# Encoding document 6200/50000...
# Encoding document 6201/50000...
# Encoding document 6202/50000...
# Encoding document 6203/50000...
# Encoding document 6204/50000...
# Encoding document 6205/50000...
# Encoding document 6206/50000...
# Encoding document 6207/50000...
# Encoding document 6208/50000...
# Encoding document 6209/50000...
# Encoding document 6210/50000...
# Encoding document 6211/50000...
# Encoding document 6212/50000...
# Encoding document 6213/50000...
# Encoding document 6214/50000...
# Encoding document 6215/50000...
# Encoding document 6216/50000...
# Encoding document 6217/50000...
# Encoding document 6218/50000...
# Encoding document 6219/50000...
# Encoding document 6220/50000...
# Encoding document 6221/50000...
# Encoding document 6222/50000...
# Encoding document 6223/50000...
# Encoding document 6224/50000...
# Encoding document 6225/50000...
# Encoding document 6226/50000...
# Encoding document 6227/50000...
# Encoding document 6228/50000...
# Encoding document 6229/50000...
# Encoding document 6230/50000...
# Encoding document 6231/50000...
# Encoding document 6232/50000...
# Encoding document 6233/50000...
# Encoding document 6234/50000...
# Encoding document 6235/50000...
# Encoding document 6236/50000...
# Encoding document 6237/50000...
# Encoding document 6238/50000...
# Encoding document 6239/50000...
# Encoding document 6240/50000...
# Encoding document 6241/50000...
# Encoding document 6242/50000...
# Encoding document 6243/50000...
# Encoding document 6244/50000...
# Encoding document 6245/50000...
# Encoding document 6246/50000...
# Encoding document 6247/50000...
# Encoding document 6248/50000...
# Encoding document 6249/50000...
# Encoding document 6250/50000...
# Encoding document 6251/50000...
# Encoding document 6252/50000...
# Encoding document 6253/50000...
# Encoding document 6254/50000...
# Encoding document 6255/50000...
# Encoding document 6256/50000...
# Encoding document 6257/50000...
# Encoding document 6258/50000...
# Encoding document 6259/50000...
# Encoding document 6260/50000...
# Encoding document 6261/50000...
# Encoding document 6262/50000...
# Encoding document 6263/50000...
# Encoding document 6264/50000...
# Encoding document 6265/50000...
# Encoding document 6266/50000...
# Encoding document 6267/50000...
# Encoding document 6268/50000...
# Encoding document 6269/50000...
# Encoding document 6270/50000...
# Encoding document 6271/50000...
# Encoding document 6272/50000...
# Encoding document 6273/50000...
# Encoding document 6274/50000...
# Encoding document 6275/50000...
# Encoding document 6276/50000...
# Encoding document 6277/50000...
# Encoding document 6278/50000...
# Encoding document 6279/50000...
# Encoding document 6280/50000...
# Encoding document 6281/50000...
# Encoding document 6282/50000...
# Encoding document 6283/50000...
# Encoding document 6284/50000...
# Encoding document 6285/50000...
# Encoding document 6286/50000...
# Encoding document 6287/50000...
# Encoding document 6288/50000...
# Encoding document 6289/50000...
# Encoding document 6290/50000...
# Encoding document 6291/50000...
# Encoding document 6292/50000...
# Encoding document 6293/50000...
# Encoding document 6294/50000...
# Encoding document 6295/50000...
# Encoding document 6296/50000...
# Encoding document 6297/50000...
# Encoding document 6298/50000...
# Encoding document 6299/50000...
# Encoding document 6300/50000...
# Encoding document 6301/50000...
# Encoding document 6302/50000...
# Encoding document 6303/50000...
# Encoding document 6304/50000...
# Encoding document 6305/50000...
# Encoding document 6306/50000...
# Encoding document 6307/50000...
# Encoding document 6308/50000...
# Encoding document 6309/50000...
# Encoding document 6310/50000...
# Encoding document 6311/50000...
# Encoding document 6312/50000...
# Encoding document 6313/50000...
# Encoding document 6314/50000...
# Encoding document 6315/50000...
# Encoding document 6316/50000...
# Encoding document 6317/50000...
# Encoding document 6318/50000...
# Encoding document 6319/50000...
# Encoding document 6320/50000...
# Encoding document 6321/50000...
# Encoding document 6322/50000...
# Encoding document 6323/50000...
# Encoding document 6324/50000...
# Encoding document 6325/50000...
# Encoding document 6326/50000...
# Encoding document 6327/50000...
# Encoding document 6328/50000...
# Encoding document 6329/50000...
# Encoding document 6330/50000...
# Encoding document 6331/50000...
# Encoding document 6332/50000...
# Encoding document 6333/50000...
# Encoding document 6334/50000...
# Encoding document 6335/50000...
# Encoding document 6336/50000...
# Encoding document 6337/50000...
# Encoding document 6338/50000...
# Encoding document 6339/50000...
# Encoding document 6340/50000...
# Encoding document 6341/50000...
# Encoding document 6342/50000...
# Encoding document 6343/50000...
# Encoding document 6344/50000...
# Encoding document 6345/50000...
# Encoding document 6346/50000...
# Encoding document 6347/50000...
# Encoding document 6348/50000...
# Encoding document 6349/50000...
# Encoding document 6350/50000...
# Encoding document 6351/50000...
# Encoding document 6352/50000...
# Encoding document 6353/50000...
# Encoding document 6354/50000...
# Encoding document 6355/50000...
# Encoding document 6356/50000...
# Encoding document 6357/50000...
# Encoding document 6358/50000...
# Encoding document 6359/50000...
# Encoding document 6360/50000...
# Encoding document 6361/50000...
# Encoding document 6362/50000...
# Encoding document 6363/50000...
# Encoding document 6364/50000...
# Encoding document 6365/50000...
# Encoding document 6366/50000...
# Encoding document 6367/50000...
# Encoding document 6368/50000...
# Encoding document 6369/50000...
# Encoding document 6370/50000...
# Encoding document 6371/50000...
# Encoding document 6372/50000...
# Encoding document 6373/50000...
# Encoding document 6374/50000...
# Encoding document 6375/50000...
# Encoding document 6376/50000...
# Encoding document 6377/50000...
# Encoding document 6378/50000...
# Encoding document 6379/50000...
# Encoding document 6380/50000...
# Encoding document 6381/50000...
# Encoding document 6382/50000...
# Encoding document 6383/50000...
# Encoding document 6384/50000...
# Encoding document 6385/50000...
# Encoding document 6386/50000...
# Encoding document 6387/50000...
# Encoding document 6388/50000...
# Encoding document 6389/50000...
# Encoding document 6390/50000...
# Encoding document 6391/50000...
# Encoding document 6392/50000...
# Encoding document 6393/50000...
# Encoding document 6394/50000...
# Encoding document 6395/50000...
# Encoding document 6396/50000...
# Encoding document 6397/50000...
# Encoding document 6398/50000...
# Encoding document 6399/50000...
# Encoding document 6400/50000...
# Encoding document 6401/50000...
# Encoding document 6402/50000...
# Encoding document 6403/50000...
# Encoding document 6404/50000...
# Encoding document 6405/50000...
# Encoding document 6406/50000...
# Encoding document 6407/50000...
# Encoding document 6408/50000...
# Encoding document 6409/50000...
# Encoding document 6410/50000...
# Encoding document 6411/50000...
# Encoding document 6412/50000...
# Encoding document 6413/50000...
# Encoding document 6414/50000...
# Encoding document 6415/50000...
# Encoding document 6416/50000...
# Encoding document 6417/50000...
# Encoding document 6418/50000...
# Encoding document 6419/50000...
# Encoding document 6420/50000...
# Encoding document 6421/50000...
# Encoding document 6422/50000...
# Encoding document 6423/50000...
# Encoding document 6424/50000...
# Encoding document 6425/50000...
# Encoding document 6426/50000...
# Encoding document 6427/50000...
# Encoding document 6428/50000...
# Encoding document 6429/50000...
# Encoding document 6430/50000...
# Encoding document 6431/50000...
# Encoding document 6432/50000...
# Encoding document 6433/50000...
# Encoding document 6434/50000...
# Encoding document 6435/50000...
# Encoding document 6436/50000...
# Encoding document 6437/50000...
# Encoding document 6438/50000...
# Encoding document 6439/50000...
# Encoding document 6440/50000...
# Encoding document 6441/50000...
# Encoding document 6442/50000...
# Encoding document 6443/50000...
# Encoding document 6444/50000...
# Encoding document 6445/50000...
# Encoding document 6446/50000...
# Encoding document 6447/50000...
# Encoding document 6448/50000...
# Encoding document 6449/50000...
# Encoding document 6450/50000...
# Encoding document 6451/50000...
# Encoding document 6452/50000...
# Encoding document 6453/50000...
# Encoding document 6454/50000...
# Encoding document 6455/50000...
# Encoding document 6456/50000...
# Encoding document 6457/50000...
# Encoding document 6458/50000...
# Encoding document 6459/50000...
# Encoding document 6460/50000...
# Encoding document 6461/50000...
# Encoding document 6462/50000...
# Encoding document 6463/50000...
# Encoding document 6464/50000...
# Encoding document 6465/50000...
# Encoding document 6466/50000...
# Encoding document 6467/50000...
# Encoding document 6468/50000...
# Encoding document 6469/50000...
# Encoding document 6470/50000...
# Encoding document 6471/50000...
# Encoding document 6472/50000...
# Encoding document 6473/50000...
# Encoding document 6474/50000...
# Encoding document 6475/50000...
# Encoding document 6476/50000...
# Encoding document 6477/50000...
# Encoding document 6478/50000...
# Encoding document 6479/50000...
# Encoding document 6480/50000...
# Encoding document 6481/50000...
# Encoding document 6482/50000...
# Encoding document 6483/50000...
# Encoding document 6484/50000...
# Encoding document 6485/50000...
# Encoding document 6486/50000...
# Encoding document 6487/50000...
# Encoding document 6488/50000...
# Encoding document 6489/50000...
# Encoding document 6490/50000...
# Encoding document 6491/50000...
# Encoding document 6492/50000...
# Encoding document 6493/50000...
# Encoding document 6494/50000...
# Encoding document 6495/50000...
# Encoding document 6496/50000...
# Encoding document 6497/50000...
# Encoding document 6498/50000...
# Encoding document 6499/50000...
# ...
# Encoding document 9503/50000...
# Encoding document 9504/50000...
# Encoding document 9505/50000...
# Encoding document 9506/50000...
# Encoding document 9507/50000...
# Encoding document 9508/50000...
# Encoding document 9509/50000...
# Encoding document 9510/50000...
# Encoding document 9511/50000...
# Encoding document 9512/50000...
# Encoding document 9513/50000...
# Encoding document 9514/50000...
# Encoding document 9515/50000...
# Encoding document 9516/50000...
# Encoding document 9517/50000...
# Encoding document 9518/50000...
# Encoding document 9519/50000...
# Encoding document 9520/50000...
# Encoding document 9521/50000...
# Encoding document 9522/50000...
# Encoding document 9523/50000...
# Encoding document 9524/50000...
# Encoding document 9525/50000...
# Encoding document 9526/50000...
# Encoding document 9527/50000...
# Encoding document 9528/50000...
# Encoding document 9529/50000...
# Encoding document 9530/50000...
# Encoding document 9531/50000...
# Encoding document 9532/50000...
# Encoding document 9533/50000...
# Encoding document 9534/50000...
# Encoding document 9535/50000...
# Encoding document 9536/50000...
# Encoding document 9537/50000...
# Encoding document 9538/50000...
# Encoding document 9539/50000...
# Encoding document 9540/50000...
# Encoding document 9541/50000...
# Encoding document 9542/50000...
# Encoding document 9543/50000...
# Encoding document 9544/50000...
# Encoding document 9545/50000...
# Encoding document 9546/50000...
# Encoding document 9547/50000...
# Encoding document 9548/50000...
# Encoding document 9549/50000...
# Encoding document 9550/50000...
# Encoding document 9551/50000...
# Encoding document 9552/50000...
# Encoding document 9553/50000...
# Encoding document 9554/50000...
# Encoding document 9555/50000...
# Encoding document 9556/50000...
# Encoding document 9557/50000...
# Encoding document 9558/50000...
# Encoding document 9559/50000...
# Encoding document 9560/50000...
# Encoding document 9561/50000...
# Encoding document 9562/50000...
# Encoding document 9563/50000...
# Encoding document 9564/50000...
# Encoding document 9565/50000...
# Encoding document 9566/50000...
# Encoding document 9567/50000...
# Encoding document 9568/50000...
# Encoding document 9569/50000...
# Encoding document 9570/50000...
# Encoding document 9571/50000...
# Encoding document 9572/50000...
# Encoding document 9573/50000...
# Encoding document 9574/50000...
# Encoding document 9575/50000...
# Encoding document 9576/50000...
# Encoding document 9577/50000...
# Encoding document 9578/50000...
# Encoding document 9579/50000...
# Encoding document 9580/50000...
# Encoding document 9581/50000...
# Encoding document 9582/50000...
# Encoding document 9583/50000...
# Encoding document 9584/50000...
# Encoding document 9585/50000...
# Encoding document 9586/50000...
# Encoding document 9587/50000...
# Encoding document 9588/50000...
# Encoding document 9589/50000...
# Encoding document 9590/50000...
# Encoding document 9591/50000...
# Encoding document 9592/50000...
# Encoding document 9593/50000...
# Encoding document 9594/50000...
# Encoding document 9595/50000...
# Encoding document 9596/50000...
# Encoding document 9597/50000...
# Encoding document 9598/50000...
# Encoding document 9599/50000...
# Encoding document 9600/50000...
# Encoding document 9601/50000...
# Encoding document 9602/50000...
# Encoding document 9603/50000...
# Encoding document 9604/50000...
# Encoding document 9605/50000...
# Encoding document 9606/50000...
# Encoding document 9607/50000...
# Encoding document 9608/50000...
# Encoding document 9609/50000...
# Encoding document 9610/50000...
# Encoding document 9611/50000...
# Encoding document 9612/50000...
# Encoding document 9613/50000...
# Encoding document 9614/50000...
# Encoding document 9615/50000...
# Encoding document 9616/50000...
# Encoding document 9617/50000...
# Encoding document 9618/50000...
# Encoding document 9619/50000...
# Encoding document 9620/50000...
# Encoding document 9621/50000...
# Encoding document 9622/50000...
# Encoding document 9623/50000...
# Encoding document 9624/50000...
# Encoding document 9625/50000...
# Encoding document 9626/50000...
# Encoding document 9627/50000...
# Encoding document 9628/50000...
# Encoding document 9629/50000...
# Encoding document 9630/50000...
# Encoding document 9631/50000...
# Encoding document 9632/50000...
# Encoding document 9633/50000...
# Encoding document 9634/50000...
# Encoding document 9635/50000...
# Encoding document 9636/50000...
# Encoding document 9637/50000...
# Encoding document 9638/50000...
# Encoding document 9639/50000...
# Encoding document 9640/50000...
# Encoding document 9641/50000...
# Encoding document 9642/50000...
# Encoding document 9643/50000...
# Encoding document 9644/50000...
# Encoding document 9645/50000...
# Encoding document 9646/50000...
# Encoding document 9647/50000...
# Encoding document 9648/50000...
# Encoding document 9649/50000...
# Encoding document 9650/50000...
# Encoding document 9651/50000...
# Encoding document 9652/50000...
# Encoding document 9653/50000...
# Encoding document 9654/50000...
# Encoding document 9655/50000...
# Encoding document 9656/50000...
# Encoding document 9657/50000...
# Encoding document 9658/50000...
# Encoding document 9659/50000...
# Encoding document 9660/50000...
# Encoding document 9661/50000...
# Encoding document 9662/50000...
# Encoding document 9663/50000...
# Encoding document 9664/50000...
# Encoding document 9665/50000...
# Encoding document 9666/50000...
# Encoding document 9667/50000...
# Encoding document 9668/50000...
# Encoding document 9669/50000...
# Encoding document 9670/50000...
# Encoding document 9671/50000...
# Encoding document 9672/50000...
# Encoding document 9673/50000...
# Encoding document 9674/50000...
# Encoding document 9675/50000...
# Encoding document 9676/50000...
# Encoding document 9677/50000...
# Encoding document 9678/50000...
# Encoding document 9679/50000...
# Encoding document 9680/50000...
# Encoding document 9681/50000...
# Encoding document 9682/50000...
# Encoding document 9683/50000...
# Encoding document 9684/50000...
# Encoding document 9685/50000...
# Encoding document 9686/50000...
# Encoding document 9687/50000...
# Encoding document 9688/50000...
# Encoding document 9689/50000...
# Encoding document 9690/50000...
# Encoding document 9691/50000...
# Encoding document 9692/50000...
# Encoding document 9693/50000...
# Encoding document 9694/50000...
# Encoding document 9695/50000...
# Encoding document 9696/50000...
# Encoding document 9697/50000...
# Encoding document 9698/50000...
# Encoding document 9699/50000...
# Encoding document 9700/50000...
# Encoding document 9701/50000...
# Encoding document 9702/50000...
# Encoding document 9703/50000...
# Encoding document 9704/50000...
# Encoding document 9705/50000...
# Encoding document 9706/50000...
# Encoding document 9707/50000...
# Encoding document 9708/50000...
# Encoding document 9709/50000...
# Encoding document 9710/50000...
# Encoding document 9711/50000...
# Encoding document 9712/50000...
# Encoding document 9713/50000...
# Encoding document 9714/50000...
# Encoding document 9715/50000...
# Encoding document 9716/50000...
# Encoding document 9717/50000...
# Encoding document 9718/50000...
# Encoding document 9719/50000...
# Encoding document 9720/50000...
# Encoding document 9721/50000...
# Encoding document 9722/50000...
# Encoding document 9723/50000...
# Encoding document 9724/50000...
# Encoding document 9725/50000...
# Encoding document 9726/50000...
# Encoding document 9727/50000...
# Encoding document 9728/50000...
# Encoding document 9729/50000...
# Encoding document 9730/50000...
# Encoding document 9731/50000...
# Encoding document 9732/50000...
# Encoding document 9733/50000...
# Encoding document 9734/50000...
# Encoding document 9735/50000...
# Encoding document 9736/50000...
# Encoding document 9737/50000...
# Encoding document 9738/50000...
# Encoding document 9739/50000...
# Encoding document 9740/50000...
# Encoding document 9741/50000...
# Encoding document 9742/50000...
# Encoding document 9743/50000...
# Encoding document 9744/50000...
# Encoding document 9745/50000...
# Encoding document 9746/50000...
# Encoding document 9747/50000...
# Encoding document 9748/50000...
# Encoding document 9749/50000...
# Encoding document 9750/50000...
# Encoding document 9751/50000...
# Encoding document 9752/50000...
# Encoding document 9753/50000...
# Encoding document 9754/50000...
# Encoding document 9755/50000...
# Encoding document 9756/50000...
# Encoding document 9757/50000...
# Encoding document 9758/50000...
# Encoding document 9759/50000...
# Encoding document 9760/50000...
# Encoding document 9761/50000...
# Encoding document 9762/50000...
# Encoding document 9763/50000...
# Encoding document 9764/50000...
# Encoding document 9765/50000...
# Encoding document 9766/50000...
# Encoding document 9767/50000...
# Encoding document 9768/50000...
# Encoding document 9769/50000...
# Encoding document 9770/50000...
# Encoding document 9771/50000...
# Encoding document 9772/50000...
# Encoding document 9773/50000...
# Encoding document 9774/50000...
# Encoding document 9775/50000...
# Encoding document 9776/50000...
# Encoding document 9777/50000...
# Encoding document 9778/50000...
# Encoding document 9779/50000...
# Encoding document 9780/50000...
# Encoding document 9781/50000...
# Encoding document 9782/50000...
# Encoding document 9783/50000...
# Encoding document 9784/50000...
# Encoding document 9785/50000...
# Encoding document 9786/50000...
# Encoding document 9787/50000...
# Encoding document 9788/50000...
# Encoding document 9789/50000...
# Encoding document 9790/50000...
# Encoding document 9791/50000...
# Encoding document 9792/50000...
# Encoding document 9793/50000...
# Encoding document 9794/50000...
# Encoding document 9795/50000...
# Encoding document 9796/50000...
# Encoding document 9797/50000...
# Encoding document 9798/50000...
# Encoding document 9799/50000...
# Encoding document 9800/50000...
# Encoding document 9801/50000...
# Encoding document 9802/50000...
# Encoding document 9803/50000...
# Encoding document 9804/50000...
# Encoding document 9805/50000...
# Encoding document 9806/50000...
# Encoding document 9807/50000...
# Encoding document 9808/50000...
# Encoding document 9809/50000...
# Encoding document 9810/50000...
# Encoding document 9811/50000...
# Encoding document 9812/50000...
# Encoding document 9813/50000...
# Encoding document 9814/50000...
# Encoding document 9815/50000...
# Encoding document 9816/50000...
# Encoding document 9817/50000...
# Encoding document 9818/50000...
# Encoding document 9819/50000...
# Encoding document 9820/50000...
# Encoding document 9821/50000...
# Encoding document 9822/50000...
# Encoding document 9823/50000...
# Encoding document 9824/50000...
# Encoding document 9825/50000...
# Encoding document 9826/50000...
# Encoding document 9827/50000...
# Encoding document 9828/50000...
# Encoding document 9829/50000...
# Encoding document 9830/50000...
# Encoding document 9831/50000...
# Encoding document 9832/50000...
# Encoding document 9833/50000...
# Encoding document 9834/50000...
# Encoding document 9835/50000...
# Encoding document 9836/50000...
# Encoding document 9837/50000...
# Encoding document 9838/50000...
# Encoding document 9839/50000...
# Encoding document 9840/50000...
# Encoding document 9841/50000...
# Encoding document 9842/50000...
# Encoding document 9843/50000...
# Encoding document 9844/50000...
# Encoding document 9845/50000...
# Encoding document 9846/50000...
# Encoding document 9847/50000...
# Encoding document 9848/50000...
# Encoding document 9849/50000...
# Encoding document 9850/50000...
# Encoding document 9851/50000...
# Encoding document 9852/50000...
# Encoding document 9853/50000...
# Encoding document 9854/50000...
# Encoding document 9855/50000...
# Encoding document 9856/50000...
# Encoding document 9857/50000...
# Encoding document 9858/50000...
# Encoding document 9859/50000...
# Encoding document 9860/50000...
# Encoding document 9861/50000...
# Encoding document 9862/50000...
# Encoding document 9863/50000...
# Encoding document 9864/50000...
# Encoding document 9865/50000...
# Encoding document 9866/50000...
# Encoding document 9867/50000...
# Encoding document 9868/50000...
# Encoding document 9869/50000...
# Encoding document 9870/50000...
# Encoding document 9871/50000...
# Encoding document 9872/50000...
# Encoding document 9873/50000...
# Encoding document 9874/50000...
# Encoding document 9875/50000...
# Encoding document 9876/50000...
# Encoding document 9877/50000...
# Encoding document 9878/50000...
# Encoding document 9879/50000...
# Encoding document 9880/50000...
# Encoding document 9881/50000...
# Encoding document 9882/50000...
# Encoding document 9883/50000...
# Encoding document 9884/50000...
# Encoding document 9885/50000...
# Encoding document 9886/50000...
# Encoding document 9887/50000...
# Encoding document 9888/50000...
# Encoding document 9889/50000...
# Encoding document 9890/50000...
# Encoding document 9891/50000...
# Encoding document 9892/50000...
# Encoding document 9893/50000...
# Encoding document 9894/50000...
# Encoding document 9895/50000...
# Encoding document 9896/50000...
# Encoding document 9897/50000...
# Encoding document 9898/50000...
# Encoding document 9899/50000...
# Encoding document 9900/50000...
# Encoding document 9901/50000...
# Encoding document 9902/50000...
# Encoding document 9903/50000...
# Encoding document 9904/50000...
# Encoding document 9905/50000...
# Encoding document 9906/50000...
# Encoding document 9907/50000...
# Encoding document 9908/50000...
# Encoding document 9909/50000...
# Encoding document 9910/50000...
# Encoding document 9911/50000...
# Encoding document 9912/50000...
# Encoding document 9913/50000...
# Encoding document 9914/50000...
# Encoding document 9915/50000...
# Encoding document 9916/50000...
# Encoding document 9917/50000...
# Encoding document 9918/50000...
# Encoding document 9919/50000...
# Encoding document 9920/50000...
# Encoding document 9921/50000...
# Encoding document 9922/50000...
# Encoding document 9923/50000...
# Encoding document 9924/50000...
# Encoding document 9925/50000...
# Encoding document 9926/50000...
# Encoding document 9927/50000...
# Encoding document 9928/50000...
# Encoding document 9929/50000...
# Encoding document 9930/50000...
# Encoding document 9931/50000...
# Encoding document 9932/50000...
# Encoding document 9933/50000...
# Encoding document 9934/50000...
# Encoding document 9935/50000...
# Encoding document 9936/50000...
# Encoding document 9937/50000...
# Encoding document 9938/50000...
# Encoding document 9939/50000...
# Encoding document 9940/50000...
# Encoding document 9941/50000...
# Encoding document 9942/50000...
# Encoding document 9943/50000...
# Encoding document 9944/50000...
# Encoding document 9945/50000...
# Encoding document 9946/50000...
# Encoding document 9947/50000...
# Encoding document 9948/50000...
# Encoding document 9949/50000...
# Encoding document 9950/50000...
# Encoding document 9951/50000...
# Encoding document 9952/50000...
# Encoding document 9953/50000...
# Encoding document 9954/50000...
# Encoding document 9955/50000...
# Encoding document 9956/50000...
# Encoding document 9957/50000...
# Encoding document 9958/50000...
# Encoding document 9959/50000...
# Encoding document 9960/50000...
# Encoding document 9961/50000...
# Encoding document 9962/50000...
# Encoding document 9963/50000...
# Encoding document 9964/50000...
# Encoding document 9965/50000...
# Encoding document 9966/50000...
# Encoding document 9967/50000...
# Encoding document 9968/50000...
# Encoding document 9969/50000...
# Encoding document 9970/50000...
# Encoding document 9971/50000...
# Encoding document 9972/50000...
# Encoding document 9973/50000...
# Encoding document 9974/50000...
# Encoding document 9975/50000...
# Encoding document 9976/50000...
# Encoding document 9977/50000...
# Encoding document 9978/50000...
# Encoding document 9979/50000...
# Encoding document 9980/50000...
# Encoding document 9981/50000...
# Encoding document 9982/50000...
# Encoding document 9983/50000...
# Encoding document 9984/50000...
# Encoding document 9985/50000...
# Encoding document 9986/50000...
# Encoding document 9987/50000...
# Encoding document 9988/50000...
# Encoding document 9989/50000...
# Encoding document 9990/50000...
# Encoding document 9991/50000...
# Encoding document 9992/50000...
# Encoding document 9993/50000...
# Encoding document 9994/50000...
# Encoding document 9995/50000...
# Encoding document 9996/50000...
# Encoding document 9997/50000...
# Encoding document 9998/50000...
# Encoding document 9999/50000...
# Encoding document 10000/50000...
# FAISS index for 50K rows saved.

# %%
# ** Query Function **
def search_movies(query, top_k=5):
    """Searches Wikipedia movies using Hugging Face embeddings + FAISS."""

    # Encode query text into an embedding
    query_embedding = model.encode([query], convert_to_tensor=True).cpu().numpy()

    # Retrieve nearest neighbors
    _, indices = faiss_index.search(query_embedding, top_k)

    # Return top-K results
    return df.iloc[indices[0]][["title", "text"]]

# ** Run a Test Query **

# %%
query = "I'm trying to remember the name of this guy who's deeply involved with the LDS Church and also co-founded a major company. He served as a missionary in the Netherlands, earned a law degree from BYU, and co-founded Nu Skin Enterprises, where he was CEO. In 2020, he became the Young Men General President for the church. Who is he?"

results = search_movies(query, top_k=10)

print("\nTop-5 Similar Wikipedia Movies:")
print(results)
# Out:
# Top-5 Similar Wikipedia Movies:
#                                         title  \
# 95                             Steven J. Lund
# 3706                       Camille N. Johnson
# 9401                          John J. Nichols
# 4907                         Richard G. Moore
# 1509                        Morgan Lyon Cotti
# 8253                            Andrew Gebara
# 354                          Peter J. Lambert
# 1873                     Jørgen Watne Frydnes
# 6930                           John T. Wilcox
# 8912  List of Colorado School of Mines people
#
#                                                    text
# 95    Steven J. Lund (born October 30, 1953) is an A...
# 3706  Camille Neddo Johnson has been the 14th Primar...
# 9401  John Joseph Nichols is a United States Air For...
# 4907  Richard Garner Moore Jr. is a United States Ai...
# 1509  Morgan Lyon Cotti is an American political sci...
# 8253  Andrew J. Gebara is a United States Air Force ...
# 354   Peter J. Lambert is a retired United States Ai...
# 1873  Jørgen Watne Frydnes (born 1984) is a Norwegia...
# 6930  John T. Wilcox II is a United States Air Force...
# 8912  The following is a list of individuals associa...
